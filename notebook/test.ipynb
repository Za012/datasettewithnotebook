# %%
import pandas

# %%
df = pandas.read_json("http://datasette:8001/corp%20data/test%20csv%20refactored%206-08-21.json?_shape=array")
df
# Out:
#     rowid  OS-CCode          ISIN     CompanyName ISICfull_code  \
# 0       1    Em.1.1  US5949181045  MICROSOFT CORP         J5820
# 1       2    Em.7.1  US5949181045  MICROSOFT CORP         J5820
# 2       3    Em.7.2  US5949181045  MICROSOFT CORP         J5820
# 3       4  Em.11.18  US5949181045  MICROSOFT CORP         J5820
# 4       5   Em.11.3  US5949181045  MICROSOFT CORP         J5820
# ..    ...       ...           ...             ...           ...
# 95     96   Em.4.12  US5949181045  MICROSOFT CORP         J5820
# 96     97    EM.3.1  US5949181045  MICROSOFT CORP         J5820
# 97     98    EM.3.1  US5949181045  MICROSOFT CORP         J5820
# 98     99    EM.3.1  US5949181045  MICROSOFT CORP         J5820
# 99    100    EM.3.1  US5949181045  MICROSOFT CORP         J5820
#
#                 ISICsection_label     ISICdivision_label      ISICgroup_label  \
# 0   Information and communication  Publishing activities  Software publishing
# ...

# %%
df = pandas.read_json("http://pudl:8002/pudl/plants_entity_eia.json?_shape=array")
df
# Out:
#     plant_id_eia      plant_name_eia balancing_authority_code_eia  \
# 0              1          Sand Point                         None
# 1              2        Bankhead Dam                         SOCO
# 2              3               Barry                         SOCO
# 3              4  Walter Bouldin Dam                         SOCO
# 4              5           Chickasaw                         None
# ..           ...                 ...                          ...
# 95           166           Carpenter                         MISO
# 96           167         Cecil Lynch                         MISO
# 97           168      Hamilton Moses                         MISO
# 98           169        Harvey Couch                         MISO
# 99           170      Lake Catherine                         MISO
#
#                          balancing_authority_name_eia               city  \
# 0                                                None         Sand Point
# ...
